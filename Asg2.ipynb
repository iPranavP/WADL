# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
import tensorflow.keras.models as models
import tensorflow.keras.layers as layers
# import tensorflow.keras.optimizers as optimizers
import tensorflow.keras.datasets as datasets
# import tensorflow.keras.backend as backend
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Practice/CIFR(Ass2&3)/train_data.csv').values
test_data = pd.read_csv('/content/drive/MyDrive/Practice/CIFR(Ass2&3)/test_data.csv').values

# %%
train_images = train_data[:,:3072]
train_labels = train_data[:,3072]

test_images = test_data[:,:3072]
test_labels = test_data[:,3072]

# %%
print(train_images.shape)
print(train_labels.shape)

print(test_images.shape)
print(test_labels.shape)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
train_images = train_images/255;
test_images = test_images/255;

# %%
model = models.Sequential()
model.add(layers.Dense(128,activation = 'sigmoid',input_shape = (32 * 32 * 3, )))
model.add(layers.Dense(64,activation = 'sigmoid'))
model.add(layers.Dense(10,activation = 'softmax'))

# %%
model.compile(optimizer = 'sgd', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(train_images,train_labels,epochs = 10, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 6s 8ms/step - loss: 2.2919 - accuracy: 0.1695 - val_loss: 2.2659 - val_accuracy: 0.2139
# Epoch 2/10
# 625/625 [==============================] - 5s 8ms/step - loss: 2.2452 - accuracy: 0.2448 - val_loss: 2.2219 - val_accuracy: 0.2459
# Epoch 3/10
# 625/625 [==============================] - 8s 13ms/step - loss: 2.1945 - accuracy: 0.2705 - val_loss: 2.1655 - val_accuracy: 0.2621
# Epoch 4/10
# 625/625 [==============================] - 6s 9ms/step - loss: 2.1351 - accuracy: 0.2831 - val_loss: 2.1077 - val_accuracy: 0.2793
# Epoch 5/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.0808 - accuracy: 0.2910 - val_loss: 2.0602 - val_accuracy: 0.2925
# Epoch 6/10
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0373 - accuracy: 0.2970 - val_loss: 2.0232 - val_accuracy: 0.2934
# Epoch 7/10
# ...

# %%
predictions = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='Training Loss')
plt.plot(history.history['val_accuracy'], label='Validation Loss')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend()

# %%
loss, accuracy = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.9236 - accuracy: 0.3205

# %%
print(loss, accuracy)
# Out:
# 1.9235588312149048 0.320499986410141
