# %%
file_path = r"/content/drive/MyDrive/Practice/CBOW(Ass5)/CBOW.txt"

with open(file_path, 'r') as file:
    file_contents = file.read()

# %%
file_contents
# Out:
# 'The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus. The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. This means that influenza can spread faster than COVID-19. \n\nFurther, transmission in the first 3-5 days of illness, or potentially pre-symptomatic transmission –transmission of the virus before the appearance of symptoms – is a major driver of transmission for influenza. In contrast, while we are learning that there are people who can shed COVID-19 virus 24-48 hours prior to symptom onset, at present, this does not appear to be a major driver of transmission. \n\nThe reproductive number – the number of secondary infections generated from one infected individual – is understood to be between 2 and 2.5 for COVID-19 virus, higher than for influenza. However, estimates for both COVID-19 and influenza viruses are very context and time-specific, making direct comparisons more difficult.  '

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentences = file_contents.split('.')

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Generate context-target pairs for training
window_size = 3
tokenized_sentences = tokenizer.texts_to_sequences(sentences)

data, labels = [], []
for sentence in tokenized_sentences:
    for i, target_word in enumerate(sentence):
        context = [
            sentence[j] for j in range(i - window_size, i + window_size + 1)
            if j != i and 0 <= j < len(sentence)
        ]
        data.append(context)
        labels.append(target_word)

# Convert data and labels to numpy arrays
data = pad_sequences(data)
labels = np.array(labels)

# %%
model = Sequential()
model.add(Embedding(input_dim = total_words, output_dim = 50, input_length = window_size*2))
model.add(GlobalAveragePooling1D())
model.add(Dense(total_words, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 6, 50)             5150
#
#  global_average_pooling1d_1  (None, 50)                0
#   (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 103)               5253
#
# =================================================================
# Total params: 10403 (40.64 KB)
# Trainable params: 10403 (40.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(data, labels, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 4ms/step - loss: 4.6331 - accuracy: 0.0202
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.6237 - accuracy: 0.0859
# Epoch 3/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.6160 - accuracy: 0.1061
# Epoch 4/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.6081 - accuracy: 0.1566
# Epoch 5/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.6003 - accuracy: 0.1768
# Epoch 6/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5920 - accuracy: 0.1970
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5832 - accuracy: 0.2020
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5738 - accuracy: 0.2020
# Epoch 9/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5637 - accuracy: 0.1919
# Epoch 10/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5528 - accuracy: 0.1919
# Epoch 11/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5413 - accuracy: 0.1970
# Epoch 12/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.5290 - accuracy: 0.2071
# Epoch 13/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5157 - accuracy: 0.1869
# Epoch 14/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.5016 - accuracy: 0.1869
# Epoch 15/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.4858 - accuracy: 0.1869
# Epoch 16/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.4688 - accuracy: 0.1818
# Epoch 17/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.4506 - accuracy: 0.1919
# Epoch 18/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.4312 - accuracy: 0.1919
# Epoch 19/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.4098 - accuracy: 0.1919
# Epoch 20/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.3883 - accuracy: 0.1919
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3639 - accuracy: 0.1919
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3390 - accuracy: 0.1970
# Epoch 23/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.3135 - accuracy: 0.1869
# Epoch 24/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.2865 - accuracy: 0.1869
# Epoch 25/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.2585 - accuracy: 0.1818
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.2285 - accuracy: 0.1869
# Epoch 27/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.1989 - accuracy: 0.1768
# Epoch 28/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.1692 - accuracy: 0.1717
# Epoch 29/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.1377 - accuracy: 0.1717
# Epoch 30/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.1062 - accuracy: 0.1768
# Epoch 31/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.0747 - accuracy: 0.1768
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.0416 - accuracy: 0.1768
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.0103 - accuracy: 0.1818
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9774 - accuracy: 0.1919
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9458 - accuracy: 0.1919
# Epoch 36/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9147 - accuracy: 0.1869
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.8824 - accuracy: 0.1970
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.8509 - accuracy: 0.1970
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.8193 - accuracy: 0.2020
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.7885 - accuracy: 0.1970
# Epoch 41/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.7579 - accuracy: 0.1970
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.7281 - accuracy: 0.1919
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.6989 - accuracy: 0.1919
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.6699 - accuracy: 0.2071
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.6405 - accuracy: 0.2071
# Epoch 46/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.6110 - accuracy: 0.2121
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.5828 - accuracy: 0.2071
# Epoch 48/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.5537 - accuracy: 0.1970
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.5257 - accuracy: 0.1970
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.4979 - accuracy: 0.2020
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.4712 - accuracy: 0.2020
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.4437 - accuracy: 0.2020
# Epoch 53/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.4174 - accuracy: 0.1970
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3908 - accuracy: 0.1919
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3646 - accuracy: 0.1919
# Epoch 56/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3392 - accuracy: 0.1970
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3131 - accuracy: 0.2020
# Epoch 58/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.2878 - accuracy: 0.2121
# Epoch 59/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.2633 - accuracy: 0.2121
# Epoch 60/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.2381 - accuracy: 0.2071
# Epoch 61/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.2140 - accuracy: 0.2020
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1900 - accuracy: 0.2020
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1658 - accuracy: 0.2071
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1417 - accuracy: 0.2121
# Epoch 65/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1185 - accuracy: 0.2222
# Epoch 66/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.0952 - accuracy: 0.2273
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.0731 - accuracy: 0.2323
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.0501 - accuracy: 0.2475
# Epoch 69/200
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0283 - accuracy: 0.2576
# Epoch 70/200
# 7/7 [==============================] - 0s 13ms/step - loss: 3.0058 - accuracy: 0.2576
# Epoch 71/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.9836 - accuracy: 0.2727
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.9616 - accuracy: 0.2727
# Epoch 73/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.9405 - accuracy: 0.2778
# Epoch 74/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.9188 - accuracy: 0.2980
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8984 - accuracy: 0.3081
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8773 - accuracy: 0.3131
# Epoch 77/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.8561 - accuracy: 0.3232
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8363 - accuracy: 0.3131
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8154 - accuracy: 0.3182
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.7954 - accuracy: 0.3283
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.7754 - accuracy: 0.3333
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.7550 - accuracy: 0.3586
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.7352 - accuracy: 0.3636
# Epoch 84/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.7155 - accuracy: 0.3737
# Epoch 85/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.6958 - accuracy: 0.3687
# Epoch 86/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6761 - accuracy: 0.3838
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.6568 - accuracy: 0.4040
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.6375 - accuracy: 0.4040
# Epoch 89/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.6194 - accuracy: 0.3990
# Epoch 90/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6005 - accuracy: 0.3990
# Epoch 91/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5819 - accuracy: 0.4040
# Epoch 92/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5641 - accuracy: 0.4091
# Epoch 93/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.5468 - accuracy: 0.4242
# Epoch 94/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.5285 - accuracy: 0.4242
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5113 - accuracy: 0.4242
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.4936 - accuracy: 0.4293
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.4753 - accuracy: 0.4343
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.4583 - accuracy: 0.4545
# Epoch 99/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.4407 - accuracy: 0.4545
# Epoch 100/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.4240 - accuracy: 0.4545
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.4062 - accuracy: 0.4495
# Epoch 102/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3895 - accuracy: 0.4596
# Epoch 103/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3732 - accuracy: 0.4545
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3569 - accuracy: 0.4545
# Epoch 105/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3404 - accuracy: 0.4697
# Epoch 106/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3244 - accuracy: 0.4848
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3081 - accuracy: 0.4949
# Epoch 108/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2923 - accuracy: 0.5000
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2761 - accuracy: 0.5051
# Epoch 110/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.2605 - accuracy: 0.4949
# Epoch 111/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.2447 - accuracy: 0.4899
# Epoch 112/200
# 7/7 [==============================] - 0s 21ms/step - loss: 2.2290 - accuracy: 0.4949
# Epoch 113/200
# 7/7 [==============================] - 0s 16ms/step - loss: 2.2140 - accuracy: 0.5051
# Epoch 114/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.1987 - accuracy: 0.5202
# Epoch 115/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1831 - accuracy: 0.5354
# Epoch 116/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1680 - accuracy: 0.5303
# Epoch 117/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1521 - accuracy: 0.5354
# Epoch 118/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1375 - accuracy: 0.5404
# Epoch 119/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1228 - accuracy: 0.5303
# Epoch 120/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1085 - accuracy: 0.5354
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0936 - accuracy: 0.5455
# Epoch 122/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0783 - accuracy: 0.5505
# Epoch 123/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0633 - accuracy: 0.5505
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0488 - accuracy: 0.5505
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0350 - accuracy: 0.5606
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0207 - accuracy: 0.5707
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0073 - accuracy: 0.5657

# %%
word_embeddings = model.layers[0].get_weights()[0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

target_word = 'influenza'
target_embedding = word_embeddings[tokenizer.word_index[target_word]]

similarities = cosine_similarity(target_embedding.reshape(1, -1), word_embeddings)[0]
most_similar_indices = similarities.argsort()[-5:][::-1]

most_similar_words = [word for word, idx in tokenizer.word_index.items() if idx in most_similar_indices]

print(f"Most similar words to '{target_word}': {most_similar_words}")
# Out:
# Most similar words to 'influenza': ['influenza', 'spread', 'faster', 'learning', 'both']
